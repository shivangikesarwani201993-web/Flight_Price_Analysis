# %% [markdown]
# 1) Overall Data Analysis 📊

# %% [markdown]
# 1.1) Importing the necessary Liabraries 🧰

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1.2) Loading the dataset - Flight_Prices 📂

# %%
df=pd.read_excel('/content/Datasets/Flight Prices/flight_price.xlsx')

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# 1.3) Viewing the data using info() and describe() 🧾

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
'''
KPI's

1) Average Ticket Price by Airline
2) Average Ticket Price by Route (Source → Destination)
3) Average Price by Number of Stops
4) Flight Volume by Airline
5) Flight Volume by Source Airport
6) Monthly Price Trend
7) Average Departure Hour by Airline
8) Average Duration Per Airline
'''
# Out:
# "\nKPI's\n\n1) Average Ticket Price by Airline\n2) Average Ticket Price by Route (Source → Destination)\n3) Average Price by Number of Stops\n4) Flight Volume by Airline\n5) Flight Volume by Source Airport\n6) Monthly Price Trend\n7) Average Departure Hour by Airline\n8) Average Duration Per Airline\n"

# %% [markdown]
# Q.) Filter out the values where Airline is IndiGo

# %%
df[df["Airline"] == 'IndiGo']
# Out:
#       Airline Date_of_Journey    Source Destination            Route Dep_Time  \
# 0      IndiGo      24/03/2019  Banglore   New Delhi        BLR → DEL    22:20
# 3      IndiGo      12/05/2019   Kolkata    Banglore  CCU → NAG → BLR    18:05
# 4      IndiGo      01/03/2019  Banglore   New Delhi  BLR → NAG → DEL    16:50
# 11     IndiGo      18/04/2019   Kolkata    Banglore        CCU → BLR    20:20
# 14     IndiGo      24/04/2019   Kolkata    Banglore        CCU → BLR    17:15
# ...       ...             ...       ...         ...              ...      ...
# 10631  IndiGo      15/05/2019     Delhi      Cochin  DEL → BLR → COK    02:00
# 10641  IndiGo       6/03/2019   Chennai     Kolkata        MAA → CCU    07:55
# 10649  IndiGo       1/03/2019   Kolkata    Banglore        CCU → BLR    21:25
# 10664  IndiGo       9/04/2019  Banglore       Delhi        BLR → DEL    18:55
# 10665  IndiGo      27/04/2019   Kolkata    Banglore        CCU → BLR    15:15
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price
# 0      01:10 22 Mar   2h 50m    non-stop         No info   3897
# 3             23:30   5h 25m      1 stop         No info   6218
# 4             21:35   4h 45m      1 stop         No info  13302
# 11            22:55   2h 35m    non-stop         No info   4174
# 14            19:50   2h 35m    non-stop         No info   4804
# ...             ...      ...         ...             ...    ...
# 10631         07:45   5h 45m      1 stop         No info   6037
# 10641         10:15   2h 20m    non-stop         No info   7295
# 10649  00:05 02 Mar   2h 40m    non-stop         No info   4778
# 10664         21:50   2h 55m    non-stop         No info   4823
# 10665         17:45   2h 30m    non-stop         No info   4804
#
# [2053 rows x 11 columns]

# %% [markdown]
# Q1.) Filter out the values where Source city is Delhi

# %%
df[df["Source"] == 'Delhi']
# Out:
#                  Airline Date_of_Journey Source Destination  \
# 2            Jet Airways       9/06/2019  Delhi      Cochin
# 9      Multiple carriers      27/05/2019  Delhi      Cochin
# 10             Air India       1/06/2019  Delhi      Cochin
# 15             Air India       3/03/2019  Delhi      Cochin
# 16              SpiceJet      15/04/2019  Delhi      Cochin
# ...                  ...             ...    ...         ...
# 10669          Air India      15/06/2019  Delhi      Cochin
# 10672        Jet Airways      27/06/2019  Delhi      Cochin
# 10673        Jet Airways      27/05/2019  Delhi      Cochin
# 10676  Multiple carriers       1/05/2019  Delhi      Cochin
# 10682          Air India       9/05/2019  Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 9            DEL → BOM → COK    11:25         19:15   7h 50m      1 stop
# 10           DEL → BLR → COK    09:45         23:00  13h 15m      1 stop
# 15     DEL → AMD → BOM → COK    16:40  19:15 04 Mar  26h 35m     2 stops
# 16           DEL → PNQ → COK    08:45         13:15   4h 30m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10669        DEL → BOM → COK    08:00         19:15  11h 15m      1 stop
# 10672  DEL → AMD → BOM → COK    23:05  19:00 28 Jun  19h 55m     2 stops
# 10673  DEL → AMD → BOM → COK    13:25  04:25 28 May      15h     2 stops
# 10676        DEL → BOM → COK    10:20         19:00   8h 40m      1 stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#                    Additional_Info  Price
# 2                          No info  13882
# 9                          No info   8625
# 10                         No info   8907
# 15                         No info  14011
# 16                         No info   5830
# ...                            ...    ...
# 10669                      No info   9929
# 10672  In-flight meal not included  11150
# 10673                      No info  16704
# 10676                      No info   9794
# 10682                      No info  11753
#
# [4537 rows x 11 columns]

# %% [markdown]
# Q)Filter out the values where Airline is IndiGo and Price is more than 1000.

# %%
df[(df["Airline"] == 'IndiGo')  & (df["Price"] > 1000)]
# Out:
#       Airline Date_of_Journey    Source Destination            Route Dep_Time  \
# 0      IndiGo      24/03/2019  Banglore   New Delhi        BLR → DEL    22:20
# 3      IndiGo      12/05/2019   Kolkata    Banglore  CCU → NAG → BLR    18:05
# 4      IndiGo      01/03/2019  Banglore   New Delhi  BLR → NAG → DEL    16:50
# 11     IndiGo      18/04/2019   Kolkata    Banglore        CCU → BLR    20:20
# 14     IndiGo      24/04/2019   Kolkata    Banglore        CCU → BLR    17:15
# ...       ...             ...       ...         ...              ...      ...
# 10631  IndiGo      15/05/2019     Delhi      Cochin  DEL → BLR → COK    02:00
# 10641  IndiGo       6/03/2019   Chennai     Kolkata        MAA → CCU    07:55
# 10649  IndiGo       1/03/2019   Kolkata    Banglore        CCU → BLR    21:25
# 10664  IndiGo       9/04/2019  Banglore       Delhi        BLR → DEL    18:55
# 10665  IndiGo      27/04/2019   Kolkata    Banglore        CCU → BLR    15:15
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price
# 0      01:10 22 Mar   2h 50m    non-stop         No info   3897
# 3             23:30   5h 25m      1 stop         No info   6218
# 4             21:35   4h 45m      1 stop         No info  13302
# 11            22:55   2h 35m    non-stop         No info   4174
# 14            19:50   2h 35m    non-stop         No info   4804
# ...             ...      ...         ...             ...    ...
# 10631         07:45   5h 45m      1 stop         No info   6037
# 10641         10:15   2h 20m    non-stop         No info   7295
# 10649  00:05 02 Mar   2h 40m    non-stop         No info   4778
# 10664         21:50   2h 55m    non-stop         No info   4823
# 10665         17:45   2h 30m    non-stop         No info   4804
#
# [2053 rows x 11 columns]

# %% [markdown]
# Q) Filter out values where Airline is Jet Airways and the Source is Delhi

# %%
df[(df["Airline"] == 'Jet Airways') & (df["Source"] == 'Delhi')]
# Out:
#            Airline Date_of_Journey Source Destination                  Route  \
# 2      Jet Airways       9/06/2019  Delhi      Cochin  DEL → LKO → BOM → COK
# 17     Jet Airways      12/06/2019  Delhi      Cochin        DEL → BOM → COK
# 19     Jet Airways      27/05/2019  Delhi      Cochin        DEL → BOM → COK
# 25     Jet Airways       9/06/2019  Delhi      Cochin  DEL → IDR → BOM → COK
# 33     Jet Airways      15/06/2019  Delhi      Cochin  DEL → NAG → BOM → COK
# ...            ...             ...    ...         ...                    ...
# 10663  Jet Airways       6/06/2019  Delhi      Cochin  DEL → JAI → BOM → COK
# 10666  Jet Airways      12/06/2019  Delhi      Cochin        DEL → BOM → COK
# 10668  Jet Airways       9/05/2019  Delhi      Cochin  DEL → JDH → BOM → COK
# 10672  Jet Airways      27/06/2019  Delhi      Cochin  DEL → AMD → BOM → COK
# 10673  Jet Airways      27/05/2019  Delhi      Cochin  DEL → AMD → BOM → COK
#
#       Dep_Time  Arrival_Time Duration Total_Stops  \
# 2        09:25  04:25 10 Jun      19h     2 stops
# 17       14:00  12:35 13 Jun  22h 35m      1 stop
# 19       16:00  12:35 28 May  20h 35m      1 stop
# 25       21:25  12:35 10 Jun  15h 10m     2 stops
# 33       14:35  12:35 16 Jun      22h     2 stops
# ...        ...           ...      ...         ...
# 10663    19:30  12:35 07 Jun   17h 5m     2 stops
# 10666    18:15  19:00 13 Jun  24h 45m      1 stop
# 10668    11:40         19:00   7h 20m     2 stops
# 10672    23:05  19:00 28 Jun  19h 55m     2 stops
# 10673    13:25  04:25 28 May      15h     2 stops
#
#                    Additional_Info  Price
# 2                          No info  13882
# 17     In-flight meal not included  10262
# 19     In-flight meal not included  12898
# 25                         No info  13292
# 33     In-flight meal not included  10919
# ...                            ...    ...
# 10663  In-flight meal not included  11733
# 10666  In-flight meal not included  10262
# 10668                      No info  21219
# 10672  In-flight meal not included  11150
# 10673                      No info  16704
#
# [1586 rows x 11 columns]

# %% [markdown]
# Q) Filter out values where Price > 500 and Flight is IndiGo and Destination is Bangalore

# %%
df[(df['Price'] > 500) & (df["Airline"]== "IndiGo") & (df["Destination"]== "Banglore")]
# Out:
#       Airline Date_of_Journey   Source Destination            Route Dep_Time  \
# 3      IndiGo      12/05/2019  Kolkata    Banglore  CCU → NAG → BLR    18:05
# 11     IndiGo      18/04/2019  Kolkata    Banglore        CCU → BLR    20:20
# 14     IndiGo      24/04/2019  Kolkata    Banglore        CCU → BLR    17:15
# 133    IndiGo      15/06/2019  Kolkata    Banglore        CCU → BLR    20:25
# 188    IndiGo       3/06/2019  Kolkata    Banglore        CCU → BLR    15:30
# ...       ...             ...      ...         ...              ...      ...
# 10574  IndiGo      21/05/2019  Kolkata    Banglore  CCU → HYD → BLR    19:20
# 10620  IndiGo       6/04/2019  Kolkata    Banglore        CCU → BLR    17:15
# 10621  IndiGo      27/06/2019  Kolkata    Banglore        CCU → BLR    22:15
# 10649  IndiGo       1/03/2019  Kolkata    Banglore        CCU → BLR    21:25
# 10665  IndiGo      27/04/2019  Kolkata    Banglore        CCU → BLR    15:15
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price
# 3             23:30   5h 25m      1 stop         No info   6218
# 11            22:55   2h 35m    non-stop         No info   4174
# 14            19:50   2h 35m    non-stop         No info   4804
# 133           23:10   2h 45m    non-stop         No info   4804
# 188           18:05   2h 35m    non-stop         No info   4804
# ...             ...      ...         ...             ...    ...
# 10574         23:45   4h 25m      1 stop         No info   3574
# 10620         19:50   2h 35m    non-stop         No info   4174
# 10621  00:50 28 Jun   2h 35m    non-stop         No info   4804
# 10649  00:05 02 Mar   2h 40m    non-stop         No info   4778
# 10665         17:45   2h 30m    non-stop         No info   4804
#
# [445 rows x 11 columns]

# %% [markdown]
# Q) Filter out values where Source is Delhi and Destination is Cochin and the flight is Air India

# %%
df[(df["Source"]== 'Delhi') & (df["Destination"]== 'Cochin') & (df["Airline"]== 'Air India')]
# Out:
#          Airline Date_of_Journey Source Destination                  Route  \
# 10     Air India       1/06/2019  Delhi      Cochin        DEL → BLR → COK
# 15     Air India       3/03/2019  Delhi      Cochin  DEL → AMD → BOM → COK
# 18     Air India      12/06/2019  Delhi      Cochin  DEL → CCU → BOM → COK
# 61     Air India       3/04/2019  Delhi      Cochin        DEL → MAA → COK
# 68     Air India      21/05/2019  Delhi      Cochin  DEL → BHO → BOM → COK
# ...          ...             ...    ...         ...                    ...
# 10648  Air India       1/06/2019  Delhi      Cochin  DEL → CCU → BOM → COK
# 10652  Air India       9/03/2019  Delhi      Cochin        DEL → TRV → COK
# 10661  Air India       9/05/2019  Delhi      Cochin        DEL → BOM → COK
# 10669  Air India      15/06/2019  Delhi      Cochin        DEL → BOM → COK
# 10682  Air India       9/05/2019  Delhi      Cochin  DEL → GOI → BOM → COK
#
#       Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 10       09:45         23:00  13h 15m      1 stop         No info   8907
# 15       16:40  19:15 04 Mar  26h 35m     2 stops         No info  14011
# 18       20:15  19:15 13 Jun      23h     2 stops         No info  13381
# 61       06:05  09:25 04 Apr  27h 20m      1 stop         No info   5117
# 68       05:55         19:15  13h 20m     2 stops         No info  10861
# ...        ...           ...      ...         ...             ...    ...
# 10648    16:55  19:15 02 Jun  26h 20m     2 stops         No info  13801
# 10652    05:15  06:50 10 Mar  25h 35m      1 stop         No info   9790
# 10661    13:00         19:15   6h 15m      1 stop         No info   8372
# 10669    08:00         19:15  11h 15m      1 stop         No info   9929
# 10682    10:55         19:15   8h 20m     2 stops         No info  11753
#
# [747 rows x 11 columns]

# %% [markdown]
# 1.4) Checking Null Values.🔍

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# 1.5) Removing null values🧹

# %%
df.dropna(inplace=True)

# %% [markdown]
# 2) Column wise Exploration 📊🔍

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# 2.1) "AirLine" Column Exploration and Cleaning 🔍🧹

# %%
df["Airline"].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %% [markdown]
# Unique Airlines

# %%
df["Airline"].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %% [markdown]
# Count of Unique Airlines

# %%
df["Airline"].nunique()
# Out:
# 12

# %% [markdown]
# Using loop for getting count of all Airlines

# %%
for i in df["Airline"].unique():
  print(i, len(df[df["Airline"]== i]))
# Out:
# IndiGo 2053
# Air India 1751
# Jet Airways 3849
# SpiceJet 818
# Multiple carriers 1196
# GoAir 194
# Vistara 479
# Air Asia 319
# Vistara Premium economy 3
# Jet Airways Business 6
# Multiple carriers Premium economy 13
# Trujet 1

# %% [markdown]
# 2.2) "Date_of_Journey" Column Cleaning and Exploration. 🔍🧹

# %% [markdown]
# unique Date_of_Journey

# %%
df["Date_of_Journey"].unique()
# Out:
# array(['24/03/2019', '1/05/2019', '9/06/2019', '12/05/2019', '01/03/2019',
#        '24/06/2019', '12/03/2019', '27/05/2019', '1/06/2019',
#        '18/04/2019', '9/05/2019', '24/04/2019', '3/03/2019', '15/04/2019',
#        '12/06/2019', '6/03/2019', '21/03/2019', '3/04/2019', '6/05/2019',
#        '15/05/2019', '18/06/2019', '15/06/2019', '6/04/2019',
#        '18/05/2019', '27/06/2019', '21/05/2019', '06/03/2019',
#        '3/06/2019', '15/03/2019', '3/05/2019', '9/03/2019', '6/06/2019',
#        '24/05/2019', '09/03/2019', '1/04/2019', '21/04/2019',
#        '21/06/2019', '27/03/2019', '18/03/2019', '12/04/2019',
#        '9/04/2019', '1/03/2019', '03/03/2019', '27/04/2019'], dtype=object)

# %% [markdown]
# Count of unique Date_of_Journey

# %%
df["Date_of_Journey"].nunique()
# Out:
# 44

# %%
df["Date_of_Journey"].value_counts()
# Out:
# Date_of_Journey
# 18/05/2019    504
# 6/06/2019     503
# 21/05/2019    497
# 9/06/2019     495
# 12/06/2019    493
# 9/05/2019     484
# 21/03/2019    423
# 15/05/2019    405
# 27/05/2019    382
# 27/06/2019    355
# 24/06/2019    351
# 1/06/2019     342
# 3/06/2019     333
# 15/06/2019    328
# 24/03/2019    323
# 6/03/2019     308
# 27/03/2019    299
# 24/05/2019    286
# 6/05/2019     281
# 1/05/2019     277
# 12/05/2019    259
# 1/04/2019     257
# 3/03/2019     218
# 9/03/2019     200
# 15/03/2019    162
# 18/03/2019    156
# 01/03/2019    152
# 12/03/2019    142
# 9/04/2019     125
# 3/04/2019     110
# 21/06/2019    109
# 18/06/2019    105
# 09/03/2019    102
# 6/04/2019     100
# 03/03/2019     97
# 06/03/2019     95
# 27/04/2019     94
# 24/04/2019     92
# 3/05/2019      90
# 15/04/2019     89
# 21/04/2019     82
# 18/04/2019     67
# 12/04/2019     63
# 1/03/2019      47
# Name: count, dtype: int64

# %%
df["Date_of_Journey"][0].split('/')[1]
# Out:
# '03'

# %%
month = []
for i in df["Date_of_Journey"]:
 month.append(i.split('/')[1])

# %%
df['Months'] = month

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price Months
# 0             No info   3897     03
# 1             No info   7662     05
# 2             No info  13882     06
# 3             No info   6218     05
# 4             No info  13302     03
# ...               ...    ...    ...
# 10678         No info   4107     04
# 10679         No info   4145     04
# 10680         No info   7229     04
# 10681         No info  12648     03
# 10682         No info  11753     05
#
# [10682 rows x 12 columns]

# %%
day = []
for i in df["Date_of_Journey"]:
  day.append(i.split('/')[0])

# %%
df['Days'] = day

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price Months Days
# 0             No info   3897     03   24
# 1             No info   7662     05    1
# 2             No info  13882     06    9
# 3             No info   6218     05   12
# 4             No info  13302     03   01
# ...               ...    ...    ...  ...
# 10678         No info   4107     04    9
# 10679         No info   4145     04   27
# 10680         No info   7229     04   27
# 10681         No info  12648     03   01
# 10682         No info  11753     05    9
#
# [10682 rows x 13 columns]

# %%
year = []
for i in df["Date_of_Journey"]:
  year.append(i.split('/')[2])

# %%
df['Year'] = year

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price Months Days  Year
# 0             No info   3897     03   24  2019
# 1             No info   7662     05    1  2019
# 2             No info  13882     06    9  2019
# 3             No info   6218     05   12  2019
# 4             No info  13302     03   01  2019
# ...               ...    ...    ...  ...   ...
# 10678         No info   4107     04    9  2019
# 10679         No info   4145     04   27  2019
# 10680         No info   7229     04   27  2019
# 10681         No info  12648     03   01  2019
# 10682         No info  11753     05    9  2019
#
# [10682 rows x 14 columns]

# %% [markdown]
# Deleting columns

# %%
del df["Months"]

# %%
del df["Days"]

# %%
del df["Year"]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df["Day"] = df["Date_of_Journey"].str.split('/').str[0].astype(int)
df["Month"] = df["Date_of_Journey"].str.split('/').str[1].astype(int)
df["Year"] = df["Date_of_Journey"].str.split('/').str[2].astype(int)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302    1
#
#    Month  Year
# 0      3  2019
# 1      5  2019
# 2      6  2019
# 3      5  2019
# 4      3  2019

# %%
del df["Date_of_Journey"]

# %%
df
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price  Day  Month  \
# 0      01:10 22 Mar   2h 50m    non-stop         No info   3897   24      3
# 1             13:15   7h 25m     2 stops         No info   7662    1      5
# 2      04:25 10 Jun      19h     2 stops         No info  13882    9      6
# 3             23:30   5h 25m      1 stop         No info   6218   12      5
# 4             21:35   4h 45m      1 stop         No info  13302    1      3
# ...             ...      ...         ...             ...    ...  ...    ...
# 10678         22:25   2h 30m    non-stop         No info   4107    9      4
# 10679         23:20   2h 35m    non-stop         No info   4145   27      4
# 10680         11:20       3h    non-stop         No info   7229   27      4
# 10681         14:10   2h 40m    non-stop         No info  12648    1      3
# 10682         19:15   8h 20m     2 stops         No info  11753    9      5
#
#        Year
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
# ...     ...
# 10678  2019
# 10679  2019
# 10680  2019
# 10681  2019
# 10682  2019
#
# [10682 rows x 13 columns]

# %% [markdown]
# 2.3) "Source" Cleaning and Exploration 🔍🧹

# %% [markdown]
# Unique "Source"

# %%
df["Source"].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %% [markdown]
# Count of unique Source

# %%
df["Source"].nunique()
# Out:
# 5

# %%
df["Source"].value_counts()
# Out:
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %% [markdown]
# 2.4) "Destination" Cleaning and Exploration 🔍🧹

# %%
df["Destination"].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
df["Destination"].nunique()
# Out:
# 6

# %%
df["Destination"].value_counts()
# Out:
# Destination
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
df["Destination"] = df["Destination"].str.replace('New Delhi','Delhi')

# %%
df["Destination"].value_counts()
# Out:
# Destination
# Cochin       4536
# Banglore     2871
# Delhi        2197
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %% [markdown]
# 2.5) "Route" Column Exploration and Cleaning 🔍🧹

# %%
del df["Route"]

# %%
df
# Out:
#            Airline    Source Destination Dep_Time  Arrival_Time Duration  \
# 0           IndiGo  Banglore       Delhi    22:20  01:10 22 Mar   2h 50m
# 1        Air India   Kolkata    Banglore    05:50         13:15   7h 25m
# 2      Jet Airways     Delhi      Cochin    09:25  04:25 10 Jun      19h
# 3           IndiGo   Kolkata    Banglore    18:05         23:30   5h 25m
# 4           IndiGo  Banglore       Delhi    16:50         21:35   4h 45m
# ...            ...       ...         ...      ...           ...      ...
# 10678     Air Asia   Kolkata    Banglore    19:55         22:25   2h 30m
# 10679    Air India   Kolkata    Banglore    20:45         23:20   2h 35m
# 10680  Jet Airways  Banglore       Delhi    08:20         11:20       3h
# 10681      Vistara  Banglore       Delhi    11:30         14:10   2h 40m
# 10682    Air India     Delhi      Cochin    10:55         19:15   8h 20m
#
#       Total_Stops Additional_Info  Price  Day  Month  Year
# 0        non-stop         No info   3897   24      3  2019
# 1         2 stops         No info   7662    1      5  2019
# 2         2 stops         No info  13882    9      6  2019
# 3          1 stop         No info   6218   12      5  2019
# 4          1 stop         No info  13302    1      3  2019
# ...           ...             ...    ...  ...    ...   ...
# 10678    non-stop         No info   4107    9      4  2019
# 10679    non-stop         No info   4145   27      4  2019
# 10680    non-stop         No info   7229   27      4  2019
# 10681    non-stop         No info  12648    1      3  2019
# 10682     2 stops         No info  11753    9      5  2019
#
# [10682 rows x 12 columns]

# %% [markdown]
# 2.6) "Dep_Time" Column Cleaning and Exploration 🔍🧹

# %%
df["Dep_Hour"] = df["Dep_Time"].str.split(":").str[0].astype(int)
df["Dep_Mins"] = df["Dep_Time"].str.split(":").str[1].astype(int)

# %%
df.head()
# Out:
#        Airline    Source Destination Dep_Time  Arrival_Time Duration  \
# 0       IndiGo  Banglore       Delhi    22:20  01:10 22 Mar   2h 50m
# 1    Air India   Kolkata    Banglore    05:50         13:15   7h 25m
# 2  Jet Airways     Delhi      Cochin    09:25  04:25 10 Jun      19h
# 3       IndiGo   Kolkata    Banglore    18:05         23:30   5h 25m
# 4       IndiGo  Banglore       Delhi    16:50         21:35   4h 45m
#
#   Total_Stops Additional_Info  Price  Day  Month  Year  Dep_Hour  Dep_Mins
# 0    non-stop         No info   3897   24      3  2019        22        20
# 1     2 stops         No info   7662    1      5  2019         5        50
# 2     2 stops         No info  13882    9      6  2019         9        25
# 3      1 stop         No info   6218   12      5  2019        18         5
# 4      1 stop         No info  13302    1      3  2019        16        50

# %%
del df["Dep_Time"]

# %%
df
# Out:
#            Airline    Source Destination  Arrival_Time Duration Total_Stops  \
# 0           IndiGo  Banglore       Delhi  01:10 22 Mar   2h 50m    non-stop
# 1        Air India   Kolkata    Banglore         13:15   7h 25m     2 stops
# 2      Jet Airways     Delhi      Cochin  04:25 10 Jun      19h     2 stops
# 3           IndiGo   Kolkata    Banglore         23:30   5h 25m      1 stop
# 4           IndiGo  Banglore       Delhi         21:35   4h 45m      1 stop
# ...            ...       ...         ...           ...      ...         ...
# 10678     Air Asia   Kolkata    Banglore         22:25   2h 30m    non-stop
# 10679    Air India   Kolkata    Banglore         23:20   2h 35m    non-stop
# 10680  Jet Airways  Banglore       Delhi         11:20       3h    non-stop
# 10681      Vistara  Banglore       Delhi         14:10   2h 40m    non-stop
# 10682    Air India     Delhi      Cochin         19:15   8h 20m     2 stops
#
#       Additional_Info  Price  Day  Month  Year  Dep_Hour  Dep_Mins
# 0             No info   3897   24      3  2019        22        20
# 1             No info   7662    1      5  2019         5        50
# 2             No info  13882    9      6  2019         9        25
# 3             No info   6218   12      5  2019        18         5
# 4             No info  13302    1      3  2019        16        50
# ...               ...    ...  ...    ...   ...       ...       ...
# 10678         No info   4107    9      4  2019        19        55
# 10679         No info   4145   27      4  2019        20        45
# 10680         No info   7229   27      4  2019         8        20
# 10681         No info  12648    1      3  2019        11        30
# 10682         No info  11753    9      5  2019        10        55
#
# [10682 rows x 13 columns]

# %% [markdown]
# 2.7) "Arrival_Time" Column Cleaning and Exploration 🔍🧹

# %%
df["Arrival_HRS"]= df["Arrival_Time"].str.split(' ').str[0].str.split(':').str[0].astype(int)
df["Arrival_MINS"]= df["Arrival_Time"].str.split(' ').str[0].str.split(':').str[1].astype(int)

# %%
df.head()
# Out:
#        Airline    Source Destination  Arrival_Time Duration Total_Stops  \
# 0       IndiGo  Banglore       Delhi  01:10 22 Mar   2h 50m    non-stop
# 1    Air India   Kolkata    Banglore         13:15   7h 25m     2 stops
# 2  Jet Airways     Delhi      Cochin  04:25 10 Jun      19h     2 stops
# 3       IndiGo   Kolkata    Banglore         23:30   5h 25m      1 stop
# 4       IndiGo  Banglore       Delhi         21:35   4h 45m      1 stop
#
#   Additional_Info  Price  Day  Month  Year  Dep_Hour  Dep_Mins  Arrival_HRS  \
# 0         No info   3897   24      3  2019        22        20            1
# 1         No info   7662    1      5  2019         5        50           13
# 2         No info  13882    9      6  2019         9        25            4
# 3         No info   6218   12      5  2019        18         5           23
# 4         No info  13302    1      3  2019        16        50           21
#
#    Arrival_MINS
# 0            10
# 1            15
# 2            25
# 3            30
# 4            35

# %%
del df["Arrival_Time"]

# %%
df.head()
# Out:
#        Airline    Source Destination Duration Total_Stops Additional_Info  \
# 0       IndiGo  Banglore       Delhi   2h 50m    non-stop         No info
# 1    Air India   Kolkata    Banglore   7h 25m     2 stops         No info
# 2  Jet Airways     Delhi      Cochin      19h     2 stops         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m      1 stop         No info
# 4       IndiGo  Banglore       Delhi   4h 45m      1 stop         No info
#
#    Price  Day  Month  Year  Dep_Hour  Dep_Mins  Arrival_HRS  Arrival_MINS
# 0   3897   24      3  2019        22        20            1            10
# 1   7662    1      5  2019         5        50           13            15
# 2  13882    9      6  2019         9        25            4            25
# 3   6218   12      5  2019        18         5           23            30
# 4  13302    1      3  2019        16        50           21            35

# %% [markdown]
# 2.6) "Duration" Column Cleaning and Exploration 🔍🧹

# %%
df = df[df["Duration"] != '5m']

# %%
df["HRS"] = df["Duration"].str.split(' ').str[0].str.split('h').str[0].astype(int)*60
# Out:
# /tmp/ipython-input-2936010684.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["HRS"] = df["Duration"].str.split(' ').str[0].str.split('h').str[0].astype(int)*60

# %%
df.head()
# Out:
#        Airline    Source Destination Duration Total_Stops Additional_Info  \
# 0       IndiGo  Banglore       Delhi   2h 50m    non-stop         No info
# 1    Air India   Kolkata    Banglore   7h 25m     2 stops         No info
# 2  Jet Airways     Delhi      Cochin      19h     2 stops         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m      1 stop         No info
# 4       IndiGo  Banglore       Delhi   4h 45m      1 stop         No info
#
#    Price  Day  Month  Year  Dep_Hour  Dep_Mins  Arrival_HRS  Arrival_MINS  \
# 0   3897   24      3  2019        22        20            1            10
# 1   7662    1      5  2019         5        50           13            15
# 2  13882    9      6  2019         9        25            4            25
# 3   6218   12      5  2019        18         5           23            30
# 4  13302    1      3  2019        16        50           21            35
#
#     HRS
# 0   120
# 1   420
# 2  1140
# 3   300
# 4   240

# %%
df["MINS"] = df["Duration"].str.split(' ').str[1].str.split('m').str[0].fillna(0).astype(int)
# Out:
# /tmp/ipython-input-1498445452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MINS"] = df["Duration"].str.split(' ').str[1].str.split('m').str[0].fillna(0).astype(int)

# %%
df["Duration_In_Mins"] = df["HRS"] + df["MINS"]
# Out:
# /tmp/ipython-input-3171485674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Duration_In_Mins"] = df["HRS"] + df["MINS"]

# %%
df.head()
# Out:
#        Airline    Source Destination Duration Total_Stops Additional_Info  \
# 0       IndiGo  Banglore       Delhi   2h 50m    non-stop         No info
# 1    Air India   Kolkata    Banglore   7h 25m     2 stops         No info
# 2  Jet Airways     Delhi      Cochin      19h     2 stops         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m      1 stop         No info
# 4       IndiGo  Banglore       Delhi   4h 45m      1 stop         No info
#
#    Price  Day  Month  Year  Dep_Hour  Dep_Mins  Arrival_HRS  Arrival_MINS  \
# 0   3897   24      3  2019        22        20            1            10
# 1   7662    1      5  2019         5        50           13            15
# 2  13882    9      6  2019         9        25            4            25
# 3   6218   12      5  2019        18         5           23            30
# 4  13302    1      3  2019        16        50           21            35
#
#     HRS  MINS  Duration_In_Mins
# 0   120    50               170
# 1   420    25               445
# 2  1140     0              1140
# 3   300    25               325
# 4   240    45               285

# %%
del df["Duration"]

# %%
del df["HRS"]

# %%
del df["MINS"]

# %%
df.head()
# Out:
#        Airline    Source Destination Total_Stops Additional_Info  Price  Day  \
# 0       IndiGo  Banglore       Delhi    non-stop         No info   3897   24
# 1    Air India   Kolkata    Banglore     2 stops         No info   7662    1
# 2  Jet Airways     Delhi      Cochin     2 stops         No info  13882    9
# 3       IndiGo   Kolkata    Banglore      1 stop         No info   6218   12
# 4       IndiGo  Banglore       Delhi      1 stop         No info  13302    1
#
#    Month  Year  Dep_Hour  Dep_Mins  Arrival_HRS  Arrival_MINS  \
# 0      3  2019        22        20            1            10
# 1      5  2019         5        50           13            15
# 2      6  2019         9        25            4            25
# 3      5  2019        18         5           23            30
# 4      3  2019        16        50           21            35
#
#    Duration_In_Mins
# 0               170
# 1               445
# 2              1140
# 3               325
# 4               285

# %% [markdown]
# 2.7) Additional Info" Column Exploration and Cleaning 🔍🧹

# %%
del df["Additional_Info"]

# %% [markdown]
# 3) Data Analysis 📈

# %% [markdown]
# KPI's 🎯
# 1) Average Ticket Price by Airline
# 2) Average Ticket Price by Route (Source → Destination)
# 3) Average Price by Number of Stops
# 4) Flight Volume by Airline
# 5) Flight Volume by Source Airport
# 6) Monthly Price Trend
# 7) Average Departure Hour by Airline
# 8) Average Duration Per Airline

# %% [markdown]
# 3.1) Average Ticket Price by Airline

# %%
df.groupby("Airline")["Price"].mean().sort_values(ascending = False)
# Out:
# Airline
# Jet Airways Business                 58358.666667
# Jet Airways                          11643.923357
# Multiple carriers Premium economy    11418.846154
# Multiple carriers                    10902.678094
# Air India                             9608.019429
# Vistara Premium economy               8962.333333
# Vistara                               7796.348643
# GoAir                                 5861.056701
# IndiGo                                5673.682903
# Air Asia                              5590.260188
# SpiceJet                              4338.284841
# Trujet                                4140.000000
# Name: Price, dtype: float64

# %%
df.groupby("Airline")["Price"].mean().sort_values(ascending= False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Airline'>

# %% [markdown]
# 3.2) Average Ticket Price by Route (Source → Destination)

# %%
df.groupby(["Source","Destination"])["Price"].mean().sort_values(ascending =False)
# Out:
# Source    Destination
# Delhi     Cochin         10540.113536
# Kolkata   Banglore        9158.389411
# Banglore  Delhi           8017.464269
# Mumbai    Hyderabad       5042.083333
# Chennai   Kolkata         4789.892388
# Name: Price, dtype: float64

# %%
df.groupby(["Source","Destination"])["Price"].mean().sort_values(ascending =False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Source,Destination'>

# %% [markdown]
# 3.3) Average Price by Number of Stops

# %%
df.groupby("Total_Stops")["Price"].mean().sort_values(ascending = False)
# Out:
# Total_Stops
# 4 stops     17686.000000
# 3 stops     13112.000000
# 2 stops     12712.772219
# 1 stop      10594.123556
# non-stop     5024.900315
# Name: Price, dtype: float64

# %%
df.groupby("Total_Stops")["Price"].mean().sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Total_Stops'>

# %% [markdown]
# 3.4) Flight Volume by Airline

# %%
df["Airline"].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1750
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
df["Airline"].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Airline'>

# %% [markdown]
# 3.5) Flight Volume by Source Airport

# %%
df.groupby("Source")["Airline"].count().sort_values(ascending = False)
# Out:
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       696
# Chennai      381
# Name: Airline, dtype: int64

# %%
df.groupby("Source")["Airline"].count().sort_values(ascending = False).plot(kind = 'pie')
# Out:
# <Axes: ylabel='Airline'>

# %% [markdown]
# 3.6) Monthly Price Trend

# %%
df.groupby("Month")["Price"].mean().sort_values(ascending = False)
# Out:
# Month
# 3    10670.762027
# 5     9127.722944
# 6     8828.796134
# 4     5770.847081
# Name: Price, dtype: float64

# %%
df.groupby("Month")["Price"].mean().sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# 3.7)Average Departure Hour by Airline

# %%
df.groupby("Airline")["Dep_Hour"].mean().sort_values(ascending = False)
# Out:
# Airline
# Air Asia                             13.996865
# Jet Airways                          13.363731
# Vistara                              13.125261
# Trujet                               13.000000
# Air India                            12.321714
# SpiceJet                             12.282396
# IndiGo                               12.215295
# GoAir                                11.798969
# Vistara Premium economy              11.333333
# Jet Airways Business                 10.666667
# Multiple carriers                    10.062709
# Multiple carriers Premium economy     7.769231
# Name: Dep_Hour, dtype: float64

# %%
df.groupby("Airline")["Dep_Hour"].mean().sort_values(ascending = False).plot(kind = 'barh')
# Out:
# <Axes: ylabel='Airline'>

# %% [markdown]
# 3.8) Average Duration Per Airline

# %%
df.groupby("Airline")["Duration_In_Mins"].mean().sort_values(ascending = False)
# Out:
# Airline
# Air India                            943.517143
# Jet Airways                          849.733697
# Multiple carriers                    625.769231
# Multiple carriers Premium economy    606.538462
# Vistara                              598.413361
# Jet Airways Business                 386.666667
# Air Asia                             348.275862
# GoAir                                298.969072
# IndiGo                               285.406722
# Trujet                               195.000000
# SpiceJet                             178.484108
# Vistara Premium economy              153.333333
# Name: Duration_In_Mins, dtype: float64

# %%
df.groupby("Airline")["Duration_In_Mins"].mean().sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Airline'>
